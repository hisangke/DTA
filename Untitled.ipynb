# %%
# Out:
# {'diving': 0, 'tennis': 9, 'walk': 10, 'biking': 1, 'golf': 2, 'juggle': 3, 'jumping': 4, 'riding': 5, 'shooting': 6, 'spiking': 7, 'swing': 8}
# successfully,len(train_list) 954
# successfully,len(test_list) 645
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d10228b82907> in <module>
#     183 #conv_img = tf.placeholder(tf.float32, [None, timesteps] + shape_1 + [channels])
#     184
# --> 185 fc_img_out = FC_LSTM(fc_img, True)
#     186 conv_img_out = CONV_LSTM(conv_img, shape_1,True)
#     187
#
# <ipython-input-12-d10228b82907> in FC_LSTM(X_spa, attention)
#     151     mlstm_cell_spa = tf.contrib.rnn.MultiRNNCell([cell_spa for _ in range(n_layers)], state_is_tuple=True)
#     152     init_state_spa = mlstm_cell_spa.zero_state(n_num*batch_size, dtype=tf.float32)
# ...
